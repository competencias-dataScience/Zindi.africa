# %% [markdown]
# Hackaton: Urban Air Pollution Challenge
# =============================================
# Edimer David Jaramillo
# Abril de 2020

# %% [markdown]
# ## Instalando y cargando bibliotecas

# %%
install.packages("h2o", dependencies = TRUE)
library(tidyverse)
library(h2o)

# %% [markdown]
# ## Importando datos

# %%
load("/content/test2_sin_impute.Rdata")
load("/content/train2_sin_impute.Rdata")

# %% [markdown]
# ## Modelo XGBoost

# %%
# Iniciando h2o
h2o.init(nthreads = -1, port = 54321, max_mem_size = "10g")

# Train y Test h2o
df_train <- df_train3 %>% 
  mutate(target = log(target))

# Datos h2o
datos_h2o <- as.h2o(x = df_train, destination_frame = "datos_h2o")

particiones <- h2o.splitFrame(data = datos_h2o, ratios = c(0.7, 0.20),
                              seed = 123)
datos_train_h2o <- h2o.assign(data = particiones[[1]], key = "datos_train_H2O")
datos_val_h2o   <- h2o.assign(data = particiones[[2]], key = "datos_val_H2O")
datos_test_h2o  <- h2o.assign(data = particiones[[3]], key = "datos_test_H2O")

# Se define la variable respuesta y los predictores.
var_respuesta <- "target"

# Para este modelo se emplean todos los predictores disponibles.
predictores   <- setdiff(h2o.colnames(datos_train_h2o), var_respuesta)

# Modelo XGB h2o
xgb <- h2o.xgboost(x = predictores
                  ,y = var_respuesta
                  ,training_frame = datos_train_h2o
                  ,validation_frame = datos_val_h2o
                  ,model_id = "xgb_model_15"
                  ,stopping_rounds = 5
                  ,stopping_metric = "RMSE"
                  ,distribution = "gaussian"
                  ,score_tree_interval = 1
                  ,learn_rate=0.05
                  ,ntrees=124
                  ,subsample = 0.9
                  ,colsample_bytree = 1
                  ,tree_method = "hist"
                  ,grow_policy = "lossguide"
                  ,booster = "gbtree"
                  ,gamma = 2,
                  ,max_runtime_secs = 3600
                  ,nfolds = 10,
                  ,seed = 123,
                  max_depth = 10,
                  min_rows = 8)
# Out:
# H2O is not running yet, starting it now...
#
# Note:  In case of errors look at the following log files:
#     /tmp/RtmpOI4DGH/file7825dea0ad/h2o_UnknownUser_started_from_r.out
#     /tmp/RtmpOI4DGH/file781af7b80a/h2o_UnknownUser_started_from_r.err
#
#
# Starting H2O JVM and connecting: .. Connection successful!
#
# R is connected to the H2O cluster:
#     H2O cluster uptime:         2 seconds 561 milliseconds
#     H2O cluster timezone:       Etc/UTC
#     H2O data parsing timezone:  UTC
#     H2O cluster version:        3.30.0.1
#     H2O cluster version age:    7 days, 11 hours and 18 minutes
#     H2O cluster name:           H2O_started_from_R_root_eby622
#     H2O cluster total nodes:    1
#     H2O cluster total memory:   10.00 GB
#     H2O cluster total cores:    2
#     H2O cluster allowed cores:  2
#     H2O cluster healthy:        TRUE
#     H2O Connection ip:          localhost
#     H2O Connection port:        54321
#     H2O Connection proxy:       NA
#     H2O Internal Security:      FALSE
#     H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
#     R Version:                  R version 3.6.3 (2020-02-29)
#
#   |======================================================================| 100%
#   |======================================================================| 100%

# %%
xgb
# Out:
# Model Details:
# ==============
#
# H2ORegressionModel: xgboost
# Model ID:  xgb_model_15
# Model Summary:
#   number_of_trees
# 1             119
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on training data. **
#
# MSE:  0.1772896
# RMSE:  0.4210577
# MAE:  0.3195982
# RMSLE:  0.1041796
# Mean Residual Deviance :  0.1772896
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on validation data. **
#
# MSE:  0.2930793
# RMSE:  0.541368
# MAE:  0.4070232
# RMSLE:  0.1275962
# Mean Residual Deviance :  0.2930793
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on cross-validation data. **
# ** 10-fold cross-validation on training data (Metrics computed for combined holdout predictions) **
#
# MSE:  0.2975382
# RMSE:  0.5454707
# MAE:  0.4104978
# RMSLE:  0.1325697
# Mean Residual Deviance :  0.2975382
#
#
# Cross-Validation Metrics Summary:
#                              mean           sd  cv_1_valid cv_2_valid
# mae                    0.41043672   0.01062946  0.39655095 0.41999292
# mean_residual_deviance  0.2974529  0.018754609  0.27172273 0.30919915
# mse                     0.2974529  0.018754609  0.27172273 0.30919915
# r2                      0.5126942  0.022611603   0.5286399   0.518217
# residual_deviance       0.2974529  0.018754609  0.27172273 0.30919915
# rmse                   0.54515094  0.017105857   0.5212703  0.5560568
# rmsle                  0.13241252 0.0064081615 0.122714855 0.13825777
#                        cv_3_valid  cv_4_valid cv_5_valid cv_6_valid cv_7_valid
# mae                     0.4222351  0.40474132  0.4134449  0.4282911 0.39990947
# mean_residual_deviance 0.30595607  0.27610224 0.30753767 0.33477688 0.28258547
# mse                    0.30595607  0.27610224 0.30753767 0.33477688 0.28258547
# r2                     0.48618525   0.5371288   0.505948 0.46302703 0.52871853
# residual_deviance      0.30595607  0.27610224 0.30753767 0.33477688 0.28258547
# rmse                   0.55313295  0.52545434  0.5545608  0.5785991  0.5315877
# rmsle                  0.13351822 0.123686984  0.1385103 0.14176892  0.1271194
#                        cv_8_valid cv_9_valid cv_10_valid
# mae                    0.39996257 0.41200677  0.40723222
# mean_residual_deviance 0.28715488 0.30133614  0.29815763
# mse                    0.28715488 0.30133614  0.29815763
# r2                     0.52786183  0.5162667  0.51494837
# residual_deviance      0.28715488 0.30133614  0.29815763
# rmse                   0.53586835 0.54894096   0.5460381
# rmsle                   0.1325532 0.13069952   0.1352961

# %% [markdown]
# ## Predicciones

# %%
# ============================= Predicciones ====================================== #

# Train
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict)

# Test (Train)
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict)

# Test (Submission)
predichos_subm <- h2o.predict(xgb, as.h2o(df_test3)) %>%
  as.data.frame() %>% pull(predict) %>% exp()
df_test3 %>% 
  select(`Place_ID X Date`) %>% 
  mutate(target = predichos_subm) ->
  subm15

# Exportando predicciones
write.csv(subm15, file = "subm15.csv", row.names = FALSE)

RMSE <- function(pred, obs, na.rm = FALSE){
  sqrt(mean((pred - obs)^2, na.rm = na.rm))
}

data.frame(
  data = c("Train", "Test"),
  RMSE = c(RMSE(pred = predichos_train, obs = as.vector(datos_train_h2o$target)),
           RMSE(pred = predichos_test, obs = as.vector(datos_test_h2o$target)))
)
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   data  RMSE
# 1 Train 0.4210577
# 2 Test  0.5688287

# %%
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict) %>% exp()
hist(predichos_train)
# Out:
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_train”

# %%
plot(predichos_train, exp(as.vector(datos_train_h2o$target)))
# Out:
# plot without title

# %%
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict) %>% exp()
hist(predichos_test)
# Out:
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_test”

# %%
plot(predichos_test, exp(as.vector(datos_test_h2o$target)))
# Out:
# plot without title

# %%
predichos_subm <- h2o.predict(xgb, as.h2o(df_test3)) %>%
  as.data.frame() %>% pull(predict) %>% exp()
hist(predichos_subm)
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_subm”

# %%
h2o.varimp_plot(xgb, num_of_features = 30)
# Out:
# Plot with title “Variable Importance: XGBOOST”

# %%
h2o.saveModel(xgb, path = "XGB_Subm15", force = TRUE)
# Out:
# [1] "/content/XGB_Subm15/xgb_model_15"

# %%
h2o.shutdown()
