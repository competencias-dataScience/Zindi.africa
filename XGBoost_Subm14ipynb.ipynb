# %% [markdown]
# Hackaton: Urban Air Pollution Challenge
# =============================================
# Edimer David Jaramillo
# Abril de 2020

# %% [markdown]
# ## Instalando y cargando bibliotecas

# %%
install.packages("h2o", dependencies = TRUE)
library(tidyverse)
library(h2o)

# %% [markdown]
# ## Importando datos

# %%
load("/content/test2_sin_impute.Rdata")
load("/content/train2_sin_impute.Rdata")

# %% [markdown]
# ## Modelo XGBoost

# %%
# Iniciando h2o
h2o.init(nthreads = -1, port = 54321, max_mem_size = "10g")

# Train y Test h2o
df_train <- df_train3 %>% 
  mutate(target = log(target))

# Datos h2o
datos_h2o <- as.h2o(x = df_train, destination_frame = "datos_h2o")

particiones <- h2o.splitFrame(data = datos_h2o, ratios = c(0.7, 0.20),
                              seed = 123)
datos_train_h2o <- h2o.assign(data = particiones[[1]], key = "datos_train_H2O")
datos_val_h2o   <- h2o.assign(data = particiones[[2]], key = "datos_val_H2O")
datos_test_h2o  <- h2o.assign(data = particiones[[3]], key = "datos_test_H2O")

# Se define la variable respuesta y los predictores.
var_respuesta <- "target"

# Para este modelo se emplean todos los predictores disponibles.
predictores   <- setdiff(h2o.colnames(datos_train_h2o), var_respuesta)

# Modelo XGB h2o
xgb <- h2o.xgboost(x = predictores
                  ,y = var_respuesta
                  ,training_frame = datos_train_h2o
                  ,validation_frame = datos_val_h2o
                  ,model_id = "xgb_model_14"
                  ,stopping_rounds = 5
                  ,stopping_metric = "RMSE"
                  ,distribution = "gaussian"
                  ,score_tree_interval = 1
                  ,learn_rate=0.05
                  ,ntrees=124
                  ,subsample = 0.9
                  ,colsample_bytree = 1
                  ,tree_method = "hist"
                  ,grow_policy = "lossguide"
                  ,booster = "gbtree"
                  ,gamma = 1,
                  ,max_runtime_secs = 3600
                  ,nfolds = 10,
                  ,seed = 123,
                  max_depth = 10,
                  min_rows = 5)
# Out:
# H2O is not running yet, starting it now...
#
# Note:  In case of errors look at the following log files:
#     /tmp/RtmpOI4DGH/file783ef637de/h2o_UnknownUser_started_from_r.out
#     /tmp/RtmpOI4DGH/file784cac6a3a/h2o_UnknownUser_started_from_r.err
#
#
# Starting H2O JVM and connecting: .. Connection successful!
#
# R is connected to the H2O cluster:
#     H2O cluster uptime:         2 seconds 392 milliseconds
#     H2O cluster timezone:       Etc/UTC
#     H2O data parsing timezone:  UTC
#     H2O cluster version:        3.30.0.1
#     H2O cluster version age:    7 days, 10 hours and 54 minutes
#     H2O cluster name:           H2O_started_from_R_root_vvo469
#     H2O cluster total nodes:    1
#     H2O cluster total memory:   10.00 GB
#     H2O cluster total cores:    2
#     H2O cluster allowed cores:  2
#     H2O cluster healthy:        TRUE
#     H2O Connection ip:          localhost
#     H2O Connection port:        54321
#     H2O Connection proxy:       NA
#     H2O Internal Security:      FALSE
#     H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
#     R Version:                  R version 3.6.3 (2020-02-29)
#
#   |======================================================================| 100%
#   |======================================================================| 100%

# %%
xgb
# Out:
# Model Details:
# ==============
#
# H2ORegressionModel: xgboost
# Model ID:  xgb_model_14
# Model Summary:
#   number_of_trees
# 1             122
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on training data. **
#
# MSE:  0.1350224
# RMSE:  0.3674539
# MAE:  0.2774847
# RMSLE:  0.09169326
# Mean Residual Deviance :  0.1350224
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on validation data. **
#
# MSE:  0.2900788
# RMSE:  0.5385896
# MAE:  0.4044821
# RMSLE:  0.1269427
# Mean Residual Deviance :  0.2900788
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on cross-validation data. **
# ** 10-fold cross-validation on training data (Metrics computed for combined holdout predictions) **
#
# MSE:  0.2909974
# RMSE:  0.5394418
# MAE:  0.4042392
# RMSLE:  0.1314571
# Mean Residual Deviance :  0.2909974
#
#
# Cross-Validation Metrics Summary:
#                              mean          sd cv_1_valid cv_2_valid cv_3_valid
# mae                    0.40416786 0.011098306 0.38860804 0.41346017 0.41913012
# mean_residual_deviance  0.2909066 0.018870575  0.2647302  0.3025199 0.30322063
# mse                     0.2909066 0.018870575  0.2647302  0.3025199 0.30322063
# r2                       0.523423 0.023288261 0.54076993  0.5286244 0.49077907
# residual_deviance       0.2909066 0.018870575  0.2647302  0.3025199 0.30322063
# rmse                    0.5391034 0.017453521  0.5145194  0.5500181  0.5506547
# rmsle                   0.1312893  0.00659675 0.12141709 0.13726467 0.13323736
#                        cv_4_valid cv_5_valid cv_6_valid cv_7_valid cv_8_valid
# mae                    0.39897174 0.40952983 0.41981536  0.3904169  0.3966253
# mean_residual_deviance 0.27041963 0.30331987 0.32564706 0.27154815 0.28253073
# mse                    0.27041963 0.30331987 0.32564706 0.27154815 0.28253073
# r2                      0.5466555  0.5127238   0.477671   0.547126  0.5354649
# residual_deviance      0.27041963 0.30331987 0.32564706 0.27154815 0.28253073
# rmse                    0.5200189 0.55074483  0.5706549 0.52110285  0.5315362
# rmsle                   0.1224812 0.13792017 0.14026701 0.12499599 0.13193022
#                        cv_9_valid cv_10_valid
# mae                     0.4040583  0.40106282
# mean_residual_deviance  0.2935822   0.2915476
# mse                     0.2935822   0.2915476
# r2                     0.52871406   0.5257017
# residual_deviance       0.2935822   0.2915476
# rmse                   0.54183227   0.5399515
# rmsle                  0.12921922  0.13416007

# %% [markdown]
# ## Predicciones

# %%
# ============================= Predicciones ====================================== #

# Train
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict)

# Test (Train)
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict)

# Test (Submission)
predichos_subm <- h2o.predict(xgb, as.h2o(df_test3)) %>%
  as.data.frame() %>% pull(predict) %>% exp()
df_test3 %>% 
  select(`Place_ID X Date`) %>% 
  mutate(target = predichos_subm) ->
  subm14

# Exportando predicciones
write.csv(subm14, file = "subm14.csv", row.names = FALSE)

RMSE <- function(pred, obs, na.rm = FALSE){
  sqrt(mean((pred - obs)^2, na.rm = na.rm))
}

data.frame(
  data = c("Train", "Test"),
  RMSE = c(RMSE(pred = predichos_train, obs = as.vector(datos_train_h2o$target)),
           RMSE(pred = predichos_test, obs = as.vector(datos_test_h2o$target)))
)
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   data  RMSE
# 1 Train 0.3674539
# 2 Test  0.5634658

# %%
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict) %>% exp()
hist(predichos_train)
# Out:
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_train”

# %%
plot(predichos_train, exp(as.vector(datos_train_h2o$target)))
# Out:
# plot without title

# %%
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict) %>% exp()
hist(predichos_test)
# Out:
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_test”

# %%
plot(predichos_test, exp(as.vector(datos_test_h2o$target)))
# Out:
# plot without title

# %%
predichos_subm <- h2o.predict(xgb, as.h2o(df_test3)) %>%
  as.data.frame() %>% pull(predict) %>% exp()
hist(predichos_subm)
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_subm”

# %%
h2o.varimp_plot(xgb, num_of_features = 30)
# Out:
# Plot with title “Variable Importance: XGBOOST”

# %%
h2o.saveModel(xgb, path = "XGB_Subm14", force = TRUE)
# Out:
# [1] "/content/XGB_Subm14/xgb_model_14"

# %%
h2o.shutdown()
# Out:
# Are you sure you want to shutdown the H2O instance running at http://localhost:54321/ (Y/N)? Y
