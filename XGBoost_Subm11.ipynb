# %% [markdown]
# Hackaton: Urban Air Pollution Challenge
# =============================================
# Edimer David Jaramillo
# Abril de 2020

# %% [markdown]
# ## Instalando y cargando bibliotecas

# %%
install.packages("h2o", dependencies = TRUE)
library(tidyverse)
library(h2o)

# %% [markdown]
# ## Importando datos

# %%
load("/content/test2_sin_impute.Rdata")
load("/content/train2_sin_impute.Rdata")

# %% [markdown]
# ## Modelo XGBoost

# %%
# Iniciando h2o
h2o.init(nthreads = -1, port = 54321, max_mem_size = "10g")

# Train y Test h2o
df_train <- df_train3 %>% 
  mutate(target = log(target))

# Datos h2o
datos_h2o <- as.h2o(x = df_train, destination_frame = "datos_h2o")

particiones <- h2o.splitFrame(data = datos_h2o, ratios = c(0.7, 0.20),
                              seed = 123)
datos_train_h2o <- h2o.assign(data = particiones[[1]], key = "datos_train_H2O")
datos_val_h2o   <- h2o.assign(data = particiones[[2]], key = "datos_val_H2O")
datos_test_h2o  <- h2o.assign(data = particiones[[3]], key = "datos_test_H2O")

# Se define la variable respuesta y los predictores.
var_respuesta <- "target"

# Para este modelo se emplean todos los predictores disponibles.
predictores   <- setdiff(h2o.colnames(datos_train_h2o), var_respuesta)

# Modelo XGB h2o
xgb <- h2o.xgboost(x = predictores
                  ,y = var_respuesta
                  ,training_frame = datos_train_h2o
                  ,validation_frame = datos_val_h2o
                  ,model_id = "xgb_model_11"
                  ,stopping_rounds = 5
                  ,stopping_metric = "RMSE"
                  ,distribution = "gaussian"
                  ,score_tree_interval = 1
                  ,learn_rate=0.05
                  ,ntrees=1500
                  ,subsample = 0.9
                  ,colsample_bytree = 1
                  ,tree_method = "hist"
                  ,grow_policy = "lossguide"
                  ,booster = "gbtree"
                  ,gamma = 5,
                  ,max_runtime_secs = 3600
                  ,nfolds = 10,
                  ,seed = 123,
                  max_depth = 15,
                  min_rows = 10)
# Out:
#  Connection successful!
#
# R is connected to the H2O cluster:
#     H2O cluster uptime:         2 hours 12 minutes
#     H2O cluster timezone:       Etc/UTC
#     H2O data parsing timezone:  UTC
#     H2O cluster version:        3.30.0.1
#     H2O cluster version age:    7 days, 9 hours and 16 minutes
#     H2O cluster name:           H2O_started_from_R_root_znj377
#     H2O cluster total nodes:    1
#     H2O cluster total memory:   9.81 GB
#     H2O cluster total cores:    2
#     H2O cluster allowed cores:  2
#     H2O cluster healthy:        TRUE
#     H2O Connection ip:          localhost
#     H2O Connection port:        54321
#     H2O Connection proxy:       NA
#     H2O Internal Security:      FALSE
#     H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
#     R Version:                  R version 3.6.3 (2020-02-29)
#
#   |======================================================================| 100%
#   |======================================================================| 100%

# %%
xgb
# Out:
# Model Details:
# ==============
#
# H2ORegressionModel: xgboost
# Model ID:  xgb_model_11
# Model Summary:
#   number_of_trees
# 1             118
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on training data. **
#
# MSE:  0.2328103
# RMSE:  0.4825042
# MAE:  0.369312
# RMSLE:  0.1178785
# Mean Residual Deviance :  0.2328103
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on validation data. **
#
# MSE:  0.3060157
# RMSE:  0.5531869
# MAE:  0.4215597
# RMSLE:  0.1299504
# Mean Residual Deviance :  0.3060157
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on cross-validation data. **
# ** 10-fold cross-validation on training data (Metrics computed for combined holdout predictions) **
#
# MSE:  0.3096669
# RMSE:  0.5564772
# MAE:  0.4213323
# RMSLE:  0.1347348
# Mean Residual Deviance :  0.3096669
#
#
# Cross-Validation Metrics Summary:
#                              mean           sd cv_1_valid cv_2_valid cv_3_valid
# mae                    0.42125118  0.010942844  0.4056712 0.42969447 0.43414548
# mean_residual_deviance 0.30956757  0.019399084 0.28367645 0.31956968  0.3199765
# mse                    0.30956757  0.019399084 0.28367645 0.31956968  0.3199765
# r2                        0.49281  0.024125015  0.5079037   0.502058  0.4626397
# residual_deviance      0.30956757  0.019399084 0.28367645 0.31956968  0.3199765
# rmse                   0.55614555  0.017311323 0.53261286 0.56530493 0.56566465
# rmsle                  0.13458195 0.0062903594 0.12513898  0.1399219 0.13616087
#                        cv_4_valid cv_5_valid cv_6_valid cv_7_valid cv_8_valid
# mae                     0.4172332  0.4214297  0.4406033  0.4097415 0.41516876
# mean_residual_deviance 0.28953046  0.3172456 0.34972298 0.29122904  0.3006952
# mse                    0.28953046  0.3172456 0.34972298 0.29122904  0.3006952
# r2                      0.5146171 0.49035248  0.4390539 0.51430327 0.50559896
# residual_deviance      0.28953046  0.3172456 0.34972298 0.29122904  0.3006952
# rmse                   0.53808033  0.5632456  0.5913738  0.5396564 0.54835683
# rmsle                  0.12634465 0.14014354 0.14427112 0.12889627 0.13471049
#                        cv_9_valid cv_10_valid
# mae                    0.42331797  0.41550615
# mean_residual_deviance 0.31405059  0.30997914
# mse                    0.31405059  0.30997914
# r2                      0.4958563  0.49571678
# residual_deviance      0.31405059  0.30997914
# rmse                   0.56040215   0.5567577
# rmsle                  0.13283965  0.13739201

# %% [markdown]
# ## Predicciones

# %%
# ============================= Predicciones ====================================== #

# Train
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict)

# Test (Train)
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict)

# Test (Submission)
predichos_subm <- h2o.predict(xgb, as.h2o(df_test3)) %>%
  as.data.frame() %>% pull(predict) %>% exp()
df_test3 %>% 
  select(`Place_ID X Date`) %>% 
  mutate(target = predichos_subm) ->
  subm11

# Exportando predicciones
write.csv(subm11, file = "subm11.csv", row.names = FALSE)

RMSE <- function(pred, obs, na.rm = FALSE){
  sqrt(mean((pred - obs)^2, na.rm = na.rm))
}

data.frame(
  data = c("Train", "Test"),
  RMSE = c(RMSE(pred = predichos_train, obs = as.vector(datos_train_h2o$target)),
           RMSE(pred = predichos_test, obs = as.vector(datos_test_h2o$target)))
)
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   data  RMSE
# 1 Train 0.4825042
# 2 Test  0.5788432

# %%
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict) %>% exp()
hist(predichos_train)
# Out:
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_train”

# %%
plot(predichos_train, exp(as.vector(datos_train_h2o$target)))
# Out:
# plot without title

# %%
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict) %>% exp()
hist(predichos_test)
# Out:
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_test”

# %%
plot(predichos_test, exp(as.vector(datos_test_h2o$target)))
# Out:
# plot without title

# %%
predichos_subm <- h2o.predict(xgb, as.h2o(df_test3)) %>%
  as.data.frame() %>% pull(predict) %>% exp()
hist(predichos_subm)
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_subm”

# %%
h2o.varimp_plot(xgb, num_of_features = 30)
# Out:
# Plot with title “Variable Importance: XGBOOST”

# %%
h2o.saveModel(xgb, path = "XGB_Subm11", force = TRUE)
# Out:
# [1] "/content/XGB_Subm11/xgb_model_11"

# %%
h2o.shutdown()
