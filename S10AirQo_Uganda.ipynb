# %% [markdown]
# [AirQo Ugandan Air Quality Forecast Challenge](https://zindi.africa/competitions/airqo-ugandan-air-quality-forecast-challenge)
# ===========================================
# ### Modelos XGBoost con H2o en R
#
# [Edimer David Jaramillo ](https://edimer.github.io/)
# Abril de 2020

# %% [markdown]
# ## Instalación de H2o y carga de bibliotecas

# %% [markdown]
# ## Cargando datos

# %%
load("/content/df_acha_train.Rdata")
load("/content/df_acha_test.Rdata")

# %% [markdown]
# ## Distribución de variable respuesta

# %%
par(mfrow = c(1, 2))
hist(df_ancha_train$target, main = "Original")
hist(log(df_ancha_train$target), main = "Logaritmo")
# Out:
# Plot with title “Logaritmo”

# %% [markdown]
# ## Preparación de datos

# %%
# Iniciando h2o
h2o.init(nthreads = -1, port = 54321, max_mem_size = "10g")

# df_train y df_test
df_train <- df_ancha_train %>% 
  select(-ID) %>%
  mutate(target = log(target))

datos_h2o <- as.h2o(x = df_train, destination_frame = "datos_h2o")
particiones <- h2o.splitFrame(data = datos_h2o, ratios = c(0.8, 0.10),
                              seed = 123)
datos_train_h2o <- h2o.assign(data = particiones[[1]], key = "datos_train_h2o")
datos_val_h2o   <- h2o.assign(data = particiones[[2]], key = "datos_val_h2o")
datos_test_h2o  <- h2o.assign(data = particiones[[3]], key = "datos_test_h2o")

# Variable respuesta y predictores
var_respuesta <- "target"
predictores   <- setdiff(h2o.colnames(datos_train_h2o), var_respuesta)

# %% [markdown]
# ## Modelo XGBoost

# %%
xgb <- h2o.xgboost(
                  # General
                  ,x = predictores
                  ,y = var_respuesta
                  ,training_frame = datos_train_h2o
                  ,validation_frame = datos_val_h2o
                  ,model_id = "xgb3"  
                  ,stopping_metric = "RMSE"
                  ,distribution = "gaussian"

                  # Learning                
                  ,learn_rate=0.01
                  ,ntrees=20000
                  ,verbose = 1
                  ,stopping_rounds = 50
                  ,max_leaves = 100
                  ,sample_rate = 0.8
                  ,col_sample_rate_per_tree = 0.9
                  ,gamma = 5
                  ,min_rows = 10,
                  ,max_depth = 0
                  ,max_bins = 100
                  ,tree_method = "hist"
                  ,grow_policy = "lossguide"
                  ,booster = "gbtree"

                  # Cross validation
                  ,nfolds = 10
                  ,seed = 123
                  ,max_runtime_secs = 3600)
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Scoring History for Model xgb3 at 2020-04-16 02:13:45
# [1] "Model Build is 46.731168% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:46
# [1] "Model Build is 46.759638% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:47
# [1] "Model Build is 46.788168% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:48
# [1] "Model Build is 46.816695% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:49
# [1] "Model Build is 46.84525% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:50
# [1] "Model Build is 46.87372% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:51
# [1] "Model Build is 46.902665% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:52
# [1] "Model Build is 46.931112% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:53
# [1] "Model Build is 46.959555% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:54
# [1] "Model Build is 46.987972% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:55
# [1] "Model Build is 47.017% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:56
# [1] "Model Build is 47.045305% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:57
# [1] "Model Build is 47.073805% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:58
# [1] "Model Build is 47.102278% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:13:59
# [1] "Model Build is 47.1305% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:00
# [1] "Model Build is 47.159415% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:01
# [1] "Model Build is 47.187915% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:02
# [1] "Model Build is 47.217193% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:04
# [1] "Model Build is 47.24575% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:05
# [1] "Model Build is 47.27425% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:06
# [1] "Model Build is 47.302723% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:07
# [1] "Model Build is 47.331166% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:08
# [1] "Model Build is 47.35964% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:09
# [1] "Model Build is 47.388193% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:10
# [1] "Model Build is 47.417% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:11
# [1] "Model Build is 47.445473% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:12
# [1] "Model Build is 47.473943% done..."
#   |=================================                                     |  48%
# Scoring History for Model xgb3 at 2020-04-16 02:14:13
# [1] "Model Build is 47.502834% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:14
# [1] "Model Build is 47.53136% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:15
# [1] "Model Build is 47.55986% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:16
# [1] "Model Build is 47.588474% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:17
# [1] "Model Build is 47.616917% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:18
# [1] "Model Build is 47.64597% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:19
# [1] "Model Build is 47.674444% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:20
# [1] "Model Build is 47.702944% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:21
# [1] "Model Build is 47.731417% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:22
# [1] "Model Build is 47.759917% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:23
# [1] "Model Build is 47.788417% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:24
# [1] "Model Build is 47.816887% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:25
# [1] "Model Build is 47.84561% done..."
#   |==================================                                    |  48%
# Scoring History for Model xgb3 at 2020-04-16 02:14:26
# [1] "Model Build is 47.874585% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:27
# [1] "Model Build is 47.903416% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:28
# [1] "Model Build is 47.93189% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:29
# [1] "Model Build is 47.960362% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:30
# [1] "Model Build is 47.988862% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:31
# [1] "Model Build is 48.017305% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:32
# [1] "Model Build is 48.04628% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:33
# [1] "Model Build is 48.07464% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:34
# [1] "Model Build is 48.102862% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:35
# [1] "Model Build is 48.13203% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:36
# [1] "Model Build is 48.160943% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:37
# [1] "Model Build is 48.1895% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:39
# [1] "Model Build is 48.217943% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:40
# [1] "Model Build is 48.246416% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:41
# [1] "Model Build is 48.27489% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:42
# [1] "Model Build is 48.303443% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:43
# [1] "Model Build is 48.332056% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:44
# [1] "Model Build is 48.360556% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:45
# [1] "Model Build is 48.389056% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:46
# [1] "Model Build is 48.417526% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:47
# [1] "Model Build is 48.446% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:48
# [1] "Model Build is 48.474473% done..."
#   |==================================                                    |  49%
# Scoring History for Model xgb3 at 2020-04-16 02:14:49
# [1] "Model Build is 48.502946% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:50
# [1] "Model Build is 48.53186% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:51
# [1] "Model Build is 48.560444% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:52
# [1] "Model Build is 48.589388% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:53
# [1] "Model Build is 48.617944% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:54
# [1] "Model Build is 48.646387% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:55
# [1] "Model Build is 48.674834% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:56
# [1] "Model Build is 48.703307% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:57
# [1] "Model Build is 48.73175% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:58
# [1] "Model Build is 48.760223% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:14:59
# [1] "Model Build is 48.788723% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:00
# [1] "Model Build is 48.817223% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:01
# [1] "Model Build is 48.846138% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:02
# [1] "Model Build is 48.87461% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:03
# [1] "Model Build is 48.903057% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:04
# [1] "Model Build is 48.931557% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:05
# [1] "Model Build is 48.960027% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:06
# [1] "Model Build is 48.98861% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:07
# [1] "Model Build is 49.01711% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:08
# [1] "Model Build is 49.046445% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:09
# [1] "Model Build is 49.07514% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:10
# [1] "Model Build is 49.103555% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:11
# [1] "Model Build is 49.132082% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:12
# [1] "Model Build is 49.160638% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:13
# [1] "Model Build is 49.189085% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:14
# [1] "Model Build is 49.217585% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:16
# [1] "Model Build is 49.246085% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:17
# [1] "Model Build is 49.274805% done..."
#   |===================================                                   |  49%
# Scoring History for Model xgb3 at 2020-04-16 02:15:18
# [1] "Model Build is 49.303445% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:19
# [1] "Model Build is 49.332196% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:20
# [1] "Model Build is 49.360415% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:21
# [1] "Model Build is 49.388888% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:22
# [1] "Model Build is 49.417362% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:23
# [1] "Model Build is 49.445835% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:24
# [1] "Model Build is 49.474278% done..."
#   |===================================                                   |  50%
# Scoring History for Model xgb3 at 2020-04-16 02:15:25
# [1] "Model Build is 49.502835% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:26
# [1] "Model Build is 49.531445% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:27
# [1] "Model Build is 49.559888% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:28
# [1] "Model Build is 49.58836% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:29
# [1] "Model Build is 49.616584% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:30
# [1] "Model Build is 49.64522% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:31
# [1] "Model Build is 49.673668% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:32
# [1] "Model Build is 49.702665% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:33
# [1] "Model Build is 49.732026% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:34
# [1] "Model Build is 49.760693% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:35
# [1] "Model Build is 49.78911% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:36
# [1] "Model Build is 49.817556% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:37
# [1] "Model Build is 49.846026% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:38
# [1] "Model Build is 49.874473% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:39
# [1] "Model Build is 49.902916% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:41
# [1] "Model Build is 49.931446% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:42
# [1] "Model Build is 49.973416% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:43
# [1] "Model Build is 50.002% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:44
# [1] "Model Build is 50.030917% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:45
# [1] "Model Build is 50.059414% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:46
# [1] "Model Build is 50.088334% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:47
# [1] "Model Build is 50.116944% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:48
# [1] "Model Build is 50.145197% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:49
# [1] "Model Build is 50.17383% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:50
# [1] "Model Build is 50.202334% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:51
# [1] "Model Build is 50.230557% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:52
# [1] "Model Build is 50.25922% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:53
# [1] "Model Build is 50.287664% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:54
# [1] "Model Build is 50.315946% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:55
# [1] "Model Build is 50.344193% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:56
# [1] "Model Build is 50.373083% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:57
# [1] "Model Build is 50.4015% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:58
# [1] "Model Build is 50.429946% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:15:59
# [1] "Model Build is 50.45842% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:00
# [1] "Model Build is 50.486887% done..."
#   |======================================                                |  55%
# Scoring History for Model xgb3 at 2020-04-16 02:16:01
# [1] "Model Build is 54.545456% done..."
# [1] "Scoring history is not available yet..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:02
# [1] "Model Build is 54.545456% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:03
# [1] "Model Build is 54.545456% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:04
# [1] "Model Build is 54.545456% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:05
# [1] "Model Build is 54.545456% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:06
# [1] "Model Build is 54.54636% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:07
# [1] "Model Build is 54.54818% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:08
# [1] "Model Build is 54.551816% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:09
# [1] "Model Build is 54.554546% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:10
# [1] "Model Build is 54.55727% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:12
# [1] "Model Build is 54.56091% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:13
# [1] "Model Build is 54.563636% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:14
# [1] "Model Build is 54.566365% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:15
# [1] "Model Build is 54.568183% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:16
# [1] "Model Build is 54.57% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:17
# [1] "Model Build is 54.572725% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:18
# [1] "Model Build is 54.57409% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:19
# [1] "Model Build is 54.57591% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:20
# [1] "Model Build is 54.577726% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:21
# [1] "Model Build is 54.580456% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:22
# [1] "Model Build is 54.582274% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:23
# [1] "Model Build is 54.584545% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:24
# [1] "Model Build is 54.585457% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:25
# [1] "Model Build is 54.587275% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:26
# [1] "Model Build is 54.588634% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:27
# [1] "Model Build is 54.59045% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:28
# [1] "Model Build is 54.592276% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:29
# [1] "Model Build is 54.594094% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:30
# [1] "Model Build is 54.59682% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:31
# [1] "Model Build is 54.598635% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:32
# [1] "Model Build is 54.59955% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:33
# [1] "Model Build is 54.600906% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:34
# [1] "Model Build is 54.60227% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:35
# [1] "Model Build is 54.60409% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:36
# [1] "Model Build is 54.60591% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:37
# [1] "Model Build is 54.608184% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:38
# [1] "Model Build is 54.610455% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:39
# [1] "Model Build is 54.61227% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:40
# [1] "Model Build is 54.614544% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:41
# [1] "Model Build is 54.615456% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:42
# [1] "Model Build is 54.61636% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:43
# [1] "Model Build is 54.617274% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:44
# [1] "Model Build is 54.619545% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:45
# [1] "Model Build is 54.621816% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:46
# [1] "Model Build is 54.623634% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:47
# [1] "Model Build is 54.62591% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:48
# [1] "Model Build is 54.62773% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:50
# [1] "Model Build is 54.63% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:51
# [1] "Model Build is 54.631364% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:52
# [1] "Model Build is 54.63227% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:53
# [1] "Model Build is 54.63318% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:54
# [1] "Model Build is 54.635% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:55
# [1] "Model Build is 54.63682% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:56
# [1] "Model Build is 54.63909% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:57
# [1] "Model Build is 54.641366% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:58
# [1] "Model Build is 54.642725% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:16:59
# [1] "Model Build is 54.645% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:00
# [1] "Model Build is 54.64682% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:01
# [1] "Model Build is 54.647726% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:02
# [1] "Model Build is 54.64864% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:03
# [1] "Model Build is 54.649544% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:04
# [1] "Model Build is 54.65136% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:05
# [1] "Model Build is 54.65318% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:06
# [1] "Model Build is 54.65591% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:07
# [1] "Model Build is 54.65773% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:08
# [1] "Model Build is 54.659545% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:09
# [1] "Model Build is 54.661816% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:10
# [1] "Model Build is 54.664093% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:11
# [1] "Model Build is 54.665% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:12
# [1] "Model Build is 54.66591% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:13
# [1] "Model Build is 54.66727% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:14
# [1] "Model Build is 54.668635% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:15
# [1] "Model Build is 54.670453% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:16
# [1] "Model Build is 54.67227% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:17
# [1] "Model Build is 54.67409% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:18
# [1] "Model Build is 54.675907% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:19
# [1] "Model Build is 54.678184% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:20
# [1] "Model Build is 54.680455% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:21
# [1] "Model Build is 54.68227% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:22
# [1] "Model Build is 54.68409% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:23
# [1] "Model Build is 54.685% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:24
# [1] "Model Build is 54.68636% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:25
# [1] "Model Build is 54.68682% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:26
# [1] "Model Build is 54.68818% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:27
# [1] "Model Build is 54.69% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:28
# [1] "Model Build is 54.69273% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:29
# [1] "Model Build is 54.694545% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:31
# [1] "Model Build is 54.696363% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:32
# [1] "Model Build is 54.69818% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:33
# [1] "Model Build is 54.70045% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:34
# [1] "Model Build is 54.70273% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:35
# [1] "Model Build is 54.704547% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:36
# [1] "Model Build is 54.705% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:37
# [1] "Model Build is 54.706365% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:38
# [1] "Model Build is 54.70773% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:39
# [1] "Model Build is 54.70818% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:40
# [1] "Model Build is 54.70955% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:41
# [1] "Model Build is 54.711366% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:42
# [1] "Model Build is 54.713184% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:43
# [1] "Model Build is 54.715455% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:44
# [1] "Model Build is 54.717726% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:45
# [1] "Model Build is 54.719543% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:46
# [1] "Model Build is 54.72136% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:47
# [1] "Model Build is 54.72318% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:48
# [1] "Model Build is 54.725456% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:49
# [1] "Model Build is 54.72773% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:50
# [1] "Model Build is 54.72864% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:51
# [1] "Model Build is 54.72909% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:52
# [1] "Model Build is 54.73% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:53
# [1] "Model Build is 54.73091% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:54
# [1] "Model Build is 54.73273% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:55
# [1] "Model Build is 54.734546% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:56
# [1] "Model Build is 54.736364% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:57
# [1] "Model Build is 54.73818% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:58
# [1] "Model Build is 54.74045% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:17:59
# [1] "Model Build is 54.74227% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:00
# [1] "Model Build is 54.74455% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:01
# [1] "Model Build is 54.746366% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:02
# [1] "Model Build is 54.748636% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:03
# [1] "Model Build is 54.750454% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:04
# [1] "Model Build is 54.75182% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:05
# [1] "Model Build is 54.752725% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:06
# [1] "Model Build is 54.752725% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:07
# [1] "Model Build is 54.753184% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:09
# [1] "Model Build is 54.755% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:10
# [1] "Model Build is 54.757273% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:11
# [1] "Model Build is 54.75909% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:12
# [1] "Model Build is 54.76091% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:13
# [1] "Model Build is 54.76273% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:14
# [1] "Model Build is 54.764545% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:15
# [1] "Model Build is 54.76636% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:16
# [1] "Model Build is 54.76909% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:17
# [1] "Model Build is 54.77091% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:18
# [1] "Model Build is 54.77273% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:19
# [1] "Model Build is 54.774547% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:20
# [1] "Model Build is 54.77727% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:21
# [1] "Model Build is 54.77909% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:22
# [1] "Model Build is 54.780906% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:23
# [1] "Model Build is 54.782724% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:24
# [1] "Model Build is 54.783183% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:25
# [1] "Model Build is 54.78409% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:26
# [1] "Model Build is 54.78591% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:27
# [1] "Model Build is 54.786366% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:28
# [1] "Model Build is 54.78727% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:29
# [1] "Model Build is 54.78909% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:30
# [1] "Model Build is 54.79091% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:31
# [1] "Model Build is 54.792726% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:32
# [1] "Model Build is 54.794544% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:33
# [1] "Model Build is 54.79682% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:34
# [1] "Model Build is 54.79909% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:35
# [1] "Model Build is 54.80091% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:36
# [1] "Model Build is 54.822695% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:37
# [1] "Model Build is 54.851% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:38
# [1] "Model Build is 54.87958% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:39
# [1] "Model Build is 54.908085% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:40
# [1] "Model Build is 54.93656% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:41
# [1] "Model Build is 54.965025% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:42
# [1] "Model Build is 54.99356% done..."
#   |=======================================                               |  55%
# Scoring History for Model xgb3 at 2020-04-16 02:18:43
# [1] "Model Build is 55.022% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:44
# [1] "Model Build is 55.050665% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:46
# [1] "Model Build is 55.07897% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:47
# [1] "Model Build is 55.10789% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:48
# [1] "Model Build is 55.13611% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:49
# [1] "Model Build is 55.164665% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:50
# [1] "Model Build is 55.19311% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:51
# [1] "Model Build is 55.22156% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:52
# [1] "Model Build is 55.25003% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:53
# [1] "Model Build is 55.2785% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:54
# [1] "Model Build is 55.30695% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:55
# [1] "Model Build is 55.335414% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:56
# [1] "Model Build is 55.36389% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:57
# [1] "Model Build is 55.39236% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:58
# [1] "Model Build is 55.420804% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:18:59
# [1] "Model Build is 55.44925% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:00
# [1] "Model Build is 55.477697% done..."
#   |=======================================                               |  56%
# Scoring History for Model xgb3 at 2020-04-16 02:19:01
# [1] "Model Build is 55.50614% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:02
# [1] "Model Build is 55.53492% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:03
# [1] "Model Build is 55.563414% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:04
# [1] "Model Build is 55.59189% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:05
# [1] "Model Build is 55.62053% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:06
# [1] "Model Build is 55.64903% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:07
# [1] "Model Build is 55.677974% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:08
# [1] "Model Build is 55.70642% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:09
# [1] "Model Build is 55.734915% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:10
# [1] "Model Build is 55.76339% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:11
# [1] "Model Build is 55.79183% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:12
# [1] "Model Build is 55.820304% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:13
# [1] "Model Build is 55.849224% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:14
# [1] "Model Build is 55.87767% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:15
# [1] "Model Build is 55.90614% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:16
# [1] "Model Build is 55.93467% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:17
# [1] "Model Build is 55.96314% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:18
# [1] "Model Build is 55.991614% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:19
# [1] "Model Build is 56.02006% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:20
# [1] "Model Build is 56.04853% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:21
# [1] "Model Build is 56.076777% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:22
# [1] "Model Build is 56.10528% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:23
# [1] "Model Build is 56.13414% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:25
# [1] "Model Build is 56.162614% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:26
# [1] "Model Build is 56.19108% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:27
# [1] "Model Build is 56.21953% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:28
# [1] "Model Build is 56.248% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:29
# [1] "Model Build is 56.27647% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:30
# [1] "Model Build is 56.305% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:31
# [1] "Model Build is 56.33392% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:32
# [1] "Model Build is 56.36236% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:33
# [1] "Model Build is 56.391275% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:34
# [1] "Model Build is 56.41958% done..."
#   |========================================                              |  56%
# Scoring History for Model xgb3 at 2020-04-16 02:19:35
# [1] "Model Build is 56.448585% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:36
# [1] "Model Build is 56.47731% done..."
#   |========================================                              |  57%
# Scoring History for Model xgb3 at 2020-04-16 02:19:37
# [1] "Model Build is 56.50572% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:38
# [1] "Model Build is 56.53436% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:39
# [1] "Model Build is 56.562835% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:40
# [1] "Model Build is 56.59175% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:41
# [1] "Model Build is 56.62025% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:42
# [1] "Model Build is 56.64872% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:43
# [1] "Model Build is 56.67719% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:44
# [1] "Model Build is 56.705725% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:45
# [1] "Model Build is 56.73417% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:46
# [1] "Model Build is 56.76239% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:47
# [1] "Model Build is 56.79086% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:48
# [1] "Model Build is 56.81931% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:49
# [1] "Model Build is 56.84764% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:50
# [1] "Model Build is 56.87636% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:51
# [1] "Model Build is 56.90497% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:52
# [1] "Model Build is 56.933445% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:53
# [1] "Model Build is 56.96164% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:54
# [1] "Model Build is 56.99011% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:55
# [1] "Model Build is 57.018614% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:56
# [1] "Model Build is 57.047164% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:57
# [1] "Model Build is 57.07564% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:58
# [1] "Model Build is 57.10408% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:19:59
# [1] "Model Build is 57.132584% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:00
# [1] "Model Build is 57.161057% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:01
# [1] "Model Build is 57.18953% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:02
# [1] "Model Build is 57.21775% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:04
# [1] "Model Build is 57.246% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:05
# [1] "Model Build is 57.27442% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:06
# [1] "Model Build is 57.302886% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:07
# [1] "Model Build is 57.33142% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:08
# [1] "Model Build is 57.359886% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:09
# [1] "Model Build is 57.38836% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:10
# [1] "Model Build is 57.41686% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:11
# [1] "Model Build is 57.44536% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:12
# [1] "Model Build is 57.47383% done..."
#   |========================================                              |  58%
# Scoring History for Model xgb3 at 2020-04-16 02:20:13
# [1] "Model Build is 57.50244% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:14
# [1] "Model Build is 57.53153% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:15
# [1] "Model Build is 57.560027% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:16
# [1] "Model Build is 57.58847% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:17
# [1] "Model Build is 57.61689% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:18
# [1] "Model Build is 57.64533% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:19
# [1] "Model Build is 57.67386% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:20
# [1] "Model Build is 57.7023% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:21
# [1] "Model Build is 57.73075% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:22
# [1] "Model Build is 57.75925% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:23
# [1] "Model Build is 57.78747% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:24
# [1] "Model Build is 57.815945% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:25
# [1] "Model Build is 57.84444% done..."
#   |=========================================                             |  58%
# Scoring History for Model xgb3 at 2020-04-16 02:20:26
# [1] "Model Build is 57.872665% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:27
# [1] "Model Build is 57.902193% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:28
# [1] "Model Build is 57.930666% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:29
# [1] "Model Build is 57.959193% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:30
# [1] "Model Build is 57.987636% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:31
# [1] "Model Build is 58.01614% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:32
# [1] "Model Build is 58.04458% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:33
# [1] "Model Build is 58.073056% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:34
# [1] "Model Build is 58.10153% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:35
# [1] "Model Build is 58.130026% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:36
# [1] "Model Build is 58.158475% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:37
# [1] "Model Build is 58.18697% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:38
# [1] "Model Build is 58.215445% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:39
# [1] "Model Build is 58.24392% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:40
# [1] "Model Build is 58.27236% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:41
# [1] "Model Build is 58.300805% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:43
# [1] "Model Build is 58.32931% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:44
# [1] "Model Build is 58.357775% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:45
# [1] "Model Build is 58.38628% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:46
# [1] "Model Build is 58.41472% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:47
# [1] "Model Build is 58.443165% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:48
# [1] "Model Build is 58.47236% done..."
#   |=========================================                             |  59%
# Scoring History for Model xgb3 at 2020-04-16 02:20:49
# [1] "Model Build is 58.50083% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:50
# [1] "Model Build is 58.52947% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:51
# [1] "Model Build is 58.557945% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:52
# [1] "Model Build is 58.58639% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:53
# [1] "Model Build is 58.61483% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:54
# [1] "Model Build is 58.64375% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:55
# [1] "Model Build is 58.67208% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:56
# [1] "Model Build is 58.701% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:57
# [1] "Model Build is 58.72933% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:58
# [1] "Model Build is 58.75761% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:20:59
# [1] "Model Build is 58.78611% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:00
# [1] "Model Build is 58.81461% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:01
# [1] "Model Build is 58.84308% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:02
# [1] "Model Build is 58.871526% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:03
# [1] "Model Build is 58.899945% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:04
# [1] "Model Build is 58.92842% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:05
# [1] "Model Build is 58.95689% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:06
# [1] "Model Build is 58.98539% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:07
# [1] "Model Build is 59.01433% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:08
# [1] "Model Build is 59.043276% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:09
# [1] "Model Build is 59.07172% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:10
# [1] "Model Build is 59.10022% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:11
# [1] "Model Build is 59.128696% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:12
# [1] "Model Build is 59.15717% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:13
# [1] "Model Build is 59.18561% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:14
# [1] "Model Build is 59.214056% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:15
# [1] "Model Build is 59.24256% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:16
# [1] "Model Build is 59.271% done..."
#   |==========================================                            |  59%
# Scoring History for Model xgb3 at 2020-04-16 02:21:17
# [1] "Model Build is 59.29956% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:18
# [1] "Model Build is 59.328085% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:19
# [1] "Model Build is 59.35653% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:21
# [1] "Model Build is 59.38475% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:22
# [1] "Model Build is 59.41375% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:23
# [1] "Model Build is 59.44222% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:24
# [1] "Model Build is 59.470725% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:25
# [1] "Model Build is 59.49922% done..."
#   |==========================================                            |  60%
# Scoring History for Model xgb3 at 2020-04-16 02:21:26
# [1] "Model Build is 59.527725% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:27
# [1] "Model Build is 59.556276% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:28
# [1] "Model Build is 59.584945% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:29
# [1] "Model Build is 59.61339% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:30
# [1] "Model Build is 59.64189% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:31
# [1] "Model Build is 59.67039% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:32
# [1] "Model Build is 59.69886% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:33
# [1] "Model Build is 59.727335% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:34
# [1] "Model Build is 59.755915% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:35
# [1] "Model Build is 59.78442% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:36
# [1] "Model Build is 59.81289% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:37
# [1] "Model Build is 59.841335% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:38
# [1] "Model Build is 59.86983% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:39
# [1] "Model Build is 59.898305% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:40
# [1] "Model Build is 59.92681% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:41
# [1] "Model Build is 59.955275% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:42
# [1] "Model Build is 59.98381% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:43
# [1] "Model Build is 60.012054% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:44
# [1] "Model Build is 60.04078% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:45
# [1] "Model Build is 60.06922% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:46
# [1] "Model Build is 60.097665% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:47
# [1] "Model Build is 60.12622% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:48
# [1] "Model Build is 60.154694% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:49
# [1] "Model Build is 60.1832% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:50
# [1] "Model Build is 60.211664% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:51
# [1] "Model Build is 60.240114% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:52
# [1] "Model Build is 60.26858% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:53
# [1] "Model Build is 60.297054% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:54
# [1] "Model Build is 60.325557% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:55
# [1] "Model Build is 60.354525% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:56
# [1] "Model Build is 60.383475% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:57
# [1] "Model Build is 60.41194% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:21:59
# [1] "Model Build is 60.44039% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:22:00
# [1] "Model Build is 60.46886% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:22:01
# [1] "Model Build is 60.49731% done..."
#   |==========================================                            |  61%
# Scoring History for Model xgb3 at 2020-04-16 02:22:02
# [1] "Model Build is 60.525805% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:22:03
# [1] "Model Build is 60.555166% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:22:04
# [1] "Model Build is 60.58375% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:22:05
# [1] "Model Build is 60.612386% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:22:06
# [1] "Model Build is 60.64086% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:22:07
# [1] "Model Build is 60.66936% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:22:08
# [1] "Model Build is 60.69786% done..."
#   |===========================================                           |  61%
# Scoring History for Model xgb3 at 2020-04-16 02:22:09
# [1] "Model Build is 60.72636% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:22:10
# [1] "Model Build is 60.755056% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:22:11
# [1] "Model Build is 60.7835% done..."
#
# ...
# [1] "Model Build is 91.16682% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:25
# [1] "Model Build is 91.168183% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:26
# [1] "Model Build is 91.17% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:27
# [1] "Model Build is 91.171366% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:28
# [1] "Model Build is 91.173184% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:29
# [1] "Model Build is 91.175% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:30
# [1] "Model Build is 91.17636% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:31
# [1] "Model Build is 91.178185% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:32
# [1] "Model Build is 91.179544% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:33
# [1] "Model Build is 91.18136% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:34
# [1] "Model Build is 91.182274% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:35
# [1] "Model Build is 91.182274% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:36
# [1] "Model Build is 91.18409% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:37
# [1] "Model Build is 91.185457% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:38
# [1] "Model Build is 91.187274% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:39
# [1] "Model Build is 91.188633% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:40
# [1] "Model Build is 91.19046% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:41
# [1] "Model Build is 91.191816% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:42
# [1] "Model Build is 91.193634% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:43
# [1] "Model Build is 91.19545% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:44
# [1] "Model Build is 91.19682% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:45
# [1] "Model Build is 91.19773% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:46
# [1] "Model Build is 91.19773% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:47
# [1] "Model Build is 91.19955% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:48
# [1] "Model Build is 91.20091% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:49
# [1] "Model Build is 91.20273% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:50
# [1] "Model Build is 91.20455% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:51
# [1] "Model Build is 91.205907% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:52
# [1] "Model Build is 91.207725% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:53
# [1] "Model Build is 91.20909% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:54
# [1] "Model Build is 91.21091% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:55
# [1] "Model Build is 91.212726% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:56
# [1] "Model Build is 91.21409% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:57
# [1] "Model Build is 91.21409% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:58
# [1] "Model Build is 91.215% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:39:59
# [1] "Model Build is 91.21682% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:00
# [1] "Model Build is 91.21864% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:01
# [1] "Model Build is 91.22% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:02
# [1] "Model Build is 91.221815% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:03
# [1] "Model Build is 91.22318% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:04
# [1] "Model Build is 91.225% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:05
# [1] "Model Build is 91.226816% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:06
# [1] "Model Build is 91.22818% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:07
# [1] "Model Build is 91.23% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:08
# [1] "Model Build is 91.23% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:09
# [1] "Model Build is 91.23091% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:10
# [1] "Model Build is 91.23273% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:11
# [1] "Model Build is 91.23409% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:12
# [1] "Model Build is 91.234547% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:13
# [1] "Model Build is 91.235% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:14
# [1] "Model Build is 91.23591% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:15
# [1] "Model Build is 91.23727% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:17
# [1] "Model Build is 91.23909% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:18
# [1] "Model Build is 91.240454% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:19
# [1] "Model Build is 91.24227% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:20
# [1] "Model Build is 91.243184% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:21
# [1] "Model Build is 91.243184% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:22
# [1] "Model Build is 91.24454% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:23
# [1] "Model Build is 91.246367% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:24
# [1] "Model Build is 91.248184% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:25
# [1] "Model Build is 91.249543% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:26
# [1] "Model Build is 91.25136% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:27
# [1] "Model Build is 91.252726% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:28
# [1] "Model Build is 91.254544% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:29
# [1] "Model Build is 91.27947% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:30
# [1] "Model Build is 91.307664% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:31
# [1] "Model Build is 91.336083% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:32
# [1] "Model Build is 91.364527% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:33
# [1] "Model Build is 91.39275% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:34
# [1] "Model Build is 91.42094% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:35
# [1] "Model Build is 91.44914% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:36
# [1] "Model Build is 91.477334% done..."
#   |================================================================      |  92%
# Scoring History for Model xgb3 at 2020-04-16 02:40:37
# [1] "Model Build is 91.50553% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:38
# [1] "Model Build is 91.53397% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:39
# [1] "Model Build is 91.562164% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:40
# [1] "Model Build is 91.590333% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:41
# [1] "Model Build is 91.6185% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:42
# [1] "Model Build is 91.646945% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:43
# [1] "Model Build is 91.67539% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:44
# [1] "Model Build is 91.70375% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:45
# [1] "Model Build is 91.73197% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:46
# [1] "Model Build is 91.760164% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:47
# [1] "Model Build is 91.788363% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:48
# [1] "Model Build is 91.816556% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:49
# [1] "Model Build is 91.84475% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:50
# [1] "Model Build is 91.87292% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:51
# [1] "Model Build is 91.90133% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:52
# [1] "Model Build is 91.929525% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:53
# [1] "Model Build is 91.957724% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:54
# [1] "Model Build is 91.98592% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:55
# [1] "Model Build is 92.01433% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:56
# [1] "Model Build is 92.04278% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:57
# [1] "Model Build is 92.071% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:58
# [1] "Model Build is 92.099196% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:40:59
# [1] "Model Build is 92.12736% done..."
#   |=================================================================     |  92%
# Scoring History for Model xgb3 at 2020-04-16 02:41:00
# [1] "Model Build is 92.15553% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:01
# [1] "Model Build is 92.18397% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:02
# [1] "Model Build is 92.212164% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:03
# [1] "Model Build is 92.24039% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:04
# [1] "Model Build is 92.26889% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:05
# [1] "Model Build is 92.297083% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:06
# [1] "Model Build is 92.325276% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:07
# [1] "Model Build is 92.35375% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:08
# [1] "Model Build is 92.38217% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:09
# [1] "Model Build is 92.41039% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:10
# [1] "Model Build is 92.438585% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:11
# [1] "Model Build is 92.46678% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:12
# [1] "Model Build is 92.49497% done..."
#   |=================================================================     |  93%
# Scoring History for Model xgb3 at 2020-04-16 02:41:13
# [1] "Model Build is 92.52317% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:15
# [1] "Model Build is 92.55153% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:16
# [1] "Model Build is 92.57969% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:17
# [1] "Model Build is 92.60786% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:18
# [1] "Model Build is 92.636055% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:19
# [1] "Model Build is 92.66425% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:20
# [1] "Model Build is 92.69253% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:21
# [1] "Model Build is 92.72125% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:22
# [1] "Model Build is 92.74947% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:23
# [1] "Model Build is 92.77764% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:24
# [1] "Model Build is 92.80608% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:25
# [1] "Model Build is 92.834276% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:26
# [1] "Model Build is 92.862475% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:27
# [1] "Model Build is 92.89089% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:28
# [1] "Model Build is 92.91908% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:29
# [1] "Model Build is 92.94728% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:30
# [1] "Model Build is 92.975473% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:31
# [1] "Model Build is 93.003696% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:32
# [1] "Model Build is 93.03186% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:33
# [1] "Model Build is 93.06028% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:34
# [1] "Model Build is 93.08872% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:35
# [1] "Model Build is 93.117195% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:36
# [1] "Model Build is 93.14536% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:37
# [1] "Model Build is 93.17353% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:38
# [1] "Model Build is 93.20172% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:39
# [1] "Model Build is 93.229914% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:40
# [1] "Model Build is 93.25808% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:41
# [1] "Model Build is 93.2865% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:42
# [1] "Model Build is 93.314695% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:43
# [1] "Model Build is 93.34289% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:44
# [1] "Model Build is 93.37108% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:45
# [1] "Model Build is 93.39925% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:46
# [1] "Model Build is 93.427664% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:47
# [1] "Model Build is 93.456084% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:48
# [1] "Model Build is 93.484277% done..."
#   |=================================================================     |  94%
# Scoring History for Model xgb3 at 2020-04-16 02:41:49
# [1] "Model Build is 93.51247% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:50
# [1] "Model Build is 93.54094% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:51
# [1] "Model Build is 93.56914% done..."
#   |==================================================================    |  94%
# Scoring History for Model xgb3 at 2020-04-16 02:41:52
# [1] "Model Build is 93.597555% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:53
# [1] "Model Build is 93.62625% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:54
# [1] "Model Build is 93.65444% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:55
# [1] "Model Build is 93.68264% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:56
# [1] "Model Build is 93.710834% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:57
# [1] "Model Build is 93.7395% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:58
# [1] "Model Build is 93.76789% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:41:59
# [1] "Model Build is 93.79633% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:00
# [1] "Model Build is 93.82475% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:01
# [1] "Model Build is 93.852943% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:02
# [1] "Model Build is 93.881166% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:03
# [1] "Model Build is 93.90961% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:04
# [1] "Model Build is 93.93781% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:05
# [1] "Model Build is 93.966% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:06
# [1] "Model Build is 93.99414% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:07
# [1] "Model Build is 94.022334% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:08
# [1] "Model Build is 94.0505% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:10
# [1] "Model Build is 94.07878% done..."
#
# Scoring History for Model xgb3 at 2020-04-16 02:42:11
# [1] "Model Build is 94.107443% done..."
#   |======================================================================| 100%

# %% [markdown]
# ## Resultados del modelo XGBoost

# %%
xgb
# Out:
# Model Details:
# ==============
#
# H2ORegressionModel: xgboost
# Model ID:  xgb3
# Model Summary:
#   number_of_trees
# 1            1075
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on training data. **
#
# MSE:  0.1481583
# RMSE:  0.3849134
# MAE:  0.296668
# RMSLE:  0.08293255
# Mean Residual Deviance :  0.1481583
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on validation data. **
#
# MSE:  0.1852233
# RMSE:  0.4303758
# MAE:  0.3297386
# RMSLE:  0.09226328
# Mean Residual Deviance :  0.1852233
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on cross-validation data. **
# ** 10-fold cross-validation on training data (Metrics computed for combined holdout predictions) **
#
# MSE:  0.1986076
# RMSE:  0.4456541
# MAE:  0.3389443
# RMSLE:  0.09688087
# Mean Residual Deviance :  0.1986076
#
#
# Cross-Validation Metrics Summary:
#                              mean           sd cv_1_valid cv_2_valid cv_3_valid
# mae                    0.33902034  0.010033957 0.33153352 0.33223778 0.33523142
# mean_residual_deviance 0.19867311  0.013221547 0.20171879 0.18565851 0.19363454
# mse                    0.19867311  0.013221547 0.20171879 0.18565851 0.19363454
# r2                     0.49178436  0.025850236  0.4822859  0.4718089  0.5208028
# residual_deviance      0.19867311  0.013221547 0.20171879 0.18565851 0.19363454
# rmse                    0.4455116  0.014625682 0.44913116 0.43088108 0.44003925
# rmsle                  0.09679266 0.0050783255 0.10001277 0.09084865 0.09817113
#                         cv_4_valid cv_5_valid cv_6_valid cv_7_valid cv_8_valid
# mae                     0.33594313 0.35944453 0.33580914 0.35410646 0.34267223
# mean_residual_deviance  0.19525434 0.21800701 0.19818921  0.2247969 0.19639023
# mse                     0.19525434 0.21800701 0.19818921  0.2247969 0.19639023
# r2                      0.50198865   0.452458  0.4640925  0.4849977 0.49153876
# residual_deviance       0.19525434 0.21800701 0.19818921  0.2247969 0.19639023
# rmse                    0.44187593  0.4669122 0.44518447 0.47412753 0.44315937
# rmsle                  0.095623106 0.10261368 0.09490833 0.10654866 0.09509469
#                         cv_9_valid cv_10_valid
# mae                     0.33263928  0.33058602
# mean_residual_deviance  0.18739727  0.18568428
# mse                     0.18739727  0.18568428
# r2                      0.53264713   0.5152233
# residual_deviance       0.18739727  0.18568428
# rmse                    0.43289405  0.43091097
# rmsle                  0.090889655  0.09321594

# %% [markdown]
# ## Predicciones

# %%
# Train
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict) %>% exp()

# Test (Train)
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict) %>% exp()

# Test (Submission)
predichos_subm <- h2o.predict(xgb, as.h2o(df_ancha_test)) %>%
  as.data.frame() %>% pull(predict) %>% exp()

df_ancha_test %>% 
  select(ID) %>% 
  mutate(target = predichos_subm) ->
  subm10

# Exportando predicciones
write.csv(subm10, file = "subm10.csv", row.names = FALSE)
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%

# %% [markdown]
# ## RMSE Train y Test (train)

# %%
# Función
RMSE <- function(pred, obs, na.rm = FALSE){
  sqrt(mean((pred - obs)^2, na.rm = na.rm))
}

data.frame(
  data = c("Train", "Test"),
  RMSE = c(RMSE(pred = predichos_train, obs = as.vector(datos_train_h2o$target)),
           RMSE(pred = predichos_test, obs = as.vector(datos_test_h2o$target)))
)
# Out:
#   data  RMSE
# 1 Train 53.29985
# 2 Test  52.92946

# %% [markdown]
# ## Importancia de variables

# %%
h2o.varimp_plot(xgb, num_of_features = 30)
# Out:
# Plot with title “Variable Importance: XGBOOST”

# %% [markdown]
# ## Guardando modelo

# %%
h2o.saveModel(xgb, path = "XGB_S8", force = TRUE)
