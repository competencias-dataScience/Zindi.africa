# %% [markdown]
# UNICEF Arm 2030 Vision #1: Flood Prediction in Malawi
# =============================================
# Edimer David Jaramillo
# Abril de 2020

# %% [markdown]
# ## Instalando y cargando bibliotecas

# %%
install.packages("h2o", dependencies = TRUE)
library(tidyverse)
library(h2o)

# %% [markdown]
# ## Importando datos

# %%
load("/content/dataTrain.Rdata")
load("/content/dataTest.Rdata")

# %% [markdown]
# ## Modelo XGBoost

# %%
# Iniciando h2o
h2o.init(nthreads = -1, port = 54321, max_mem_size = "10g")

# Train y Test h2o
df_train <- dataTrain %>%
   select(-Square_ID)

# Datos h2o
datos_h2o <- as.h2o(x = df_train, destination_frame = "datos_h2o")

particiones <- h2o.splitFrame(data = datos_h2o, ratios = c(0.8, 0.10),
                              seed = 123)
datos_train_h2o <- h2o.assign(data = particiones[[1]], key = "datos_train_h2o")
datos_val_h2o   <- h2o.assign(data = particiones[[2]], key = "datos_val_h2o")
datos_test_h2o  <- h2o.assign(data = particiones[[3]], key = "datos_test_h2o")

# Se define la variable respuesta y los predictores.
var_respuesta <- "target_2015"

# Para este modelo se emplean todos los predictores disponibles.
predictores   <- setdiff(h2o.colnames(datos_train_h2o), var_respuesta)

# Modelo XGB h2o
xgb <- h2o.xgboost(x = predictores
                  ,y = var_respuesta
                  ,training_frame = datos_train_h2o
                  ,validation_frame = datos_val_h2o
                  ,model_id = "xgb_s6"
                  ,stopping_rounds = 3
                  ,stopping_metric = "RMSE"
                  ,distribution = "poisson"
                  ,score_tree_interval = 5
                  ,learn_rate=0.05
                  ,ntrees=1500
                  ,subsample = 1
                  ,col_sample_rate = 1
                  ,colsample_bytree = 1
                  ,tree_method = "hist"
                  ,grow_policy = "lossguide"
                  ,booster = "gbtree"
                  ,gamma = 1
                  ,max_runtime_secs = 3600
                  ,nfolds = 10
                  ,seed = 123
                  ,max_depth = 15
                  ,min_rows = 10)
# Out:
# H2O is not running yet, starting it now...
#
# Note:  In case of errors look at the following log files:
#     /tmp/RtmpaAAfAA/file7f31f26df0/h2o_UnknownUser_started_from_r.out
#     /tmp/RtmpaAAfAA/file7f18306f23/h2o_UnknownUser_started_from_r.err
#
#
# Starting H2O JVM and connecting: .. Connection successful!
#
# R is connected to the H2O cluster:
#     H2O cluster uptime:         2 seconds 478 milliseconds
#     H2O cluster timezone:       Etc/UTC
#     H2O data parsing timezone:  UTC
#     H2O cluster version:        3.30.0.1
#     H2O cluster version age:    18 days
#     H2O cluster name:           H2O_started_from_R_root_ksy003
#     H2O cluster total nodes:    1
#     H2O cluster total memory:   10.00 GB
#     H2O cluster total cores:    2
#     H2O cluster allowed cores:  2
#     H2O cluster healthy:        TRUE
#     H2O Connection ip:          localhost
#     H2O Connection port:        54321
#     H2O Connection proxy:       NA
#     H2O Internal Security:      FALSE
#     H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
#     R Version:                  R version 3.6.3 (2020-02-29)
#
#   |======================================================================| 100%
#   |======================================================================| 100%

# %%
xgb
# Out:
# Model Details:
# ==============
#
# H2ORegressionModel: xgboost
# Model ID:  xgb_s6
# Model Summary:
#   number_of_trees
# 1             179
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on training data. **
#
# MSE:  0.005216331
# RMSE:  0.07222417
# MAE:  0.02725843
# RMSLE:  0.05337071
# Mean Residual Deviance :  0.2561612
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on validation data. **
#
# MSE:  0.007556755
# RMSE:  0.0869296
# MAE:  0.03143165
# RMSLE:  0.06164437
# Mean Residual Deviance :  0.2539463
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on cross-validation data. **
# ** 10-fold cross-validation on training data (Metrics computed for combined holdout predictions) **
#
# MSE:  0.009124256
# RMSE:  0.09552097
# MAE:  0.03547263
# RMSLE:  0.06922567
# Mean Residual Deviance :  0.2754244
#
#
# Cross-Validation Metrics Summary:
#                               mean           sd  cv_1_valid  cv_2_valid
# mae                    0.035439216 0.0027245854 0.035800833  0.03272858
# mean_residual_deviance  0.27524337  0.018548347  0.27739334  0.25014874
# mse                    0.009121674  0.001228144 0.009583678 0.008049756
# r2                      0.82864255  0.019079028   0.8240561  0.83745563
# residual_deviance       0.27524337  0.018548347  0.27739334  0.25014874
# rmse                    0.09533261   0.00608902  0.09789626 0.089720435
# rmsle                    0.0690854  0.004331577 0.070996635 0.062696524
#                         cv_3_valid  cv_4_valid  cv_5_valid  cv_6_valid
# mae                    0.033257563  0.03601682  0.03360496  0.03793692
# mean_residual_deviance  0.27529225   0.2940042  0.25709832  0.27837414
# mse                    0.008334367 0.008803304 0.008513608 0.008664197
# r2                      0.83952945   0.8529412  0.82362175  0.84473085
# residual_deviance       0.27529225   0.2940042  0.25709832  0.27837414
# rmse                   0.091292754  0.09382592  0.09226922  0.09308167
# rmsle                  0.067545384 0.068261795  0.06633998 0.069131784
#                         cv_7_valid  cv_8_valid   cv_9_valid cv_10_valid
# mae                    0.034227256 0.041866433  0.034433156 0.034519643
# mean_residual_deviance  0.25108948  0.30498412    0.2922983   0.2717509
# mse                    0.009057971 0.012351968 0.0084821815 0.009375711
# r2                       0.8186491   0.7940319    0.8465536  0.80485576
# residual_deviance       0.25108948  0.30498412    0.2922983   0.2717509
# rmse                   0.095173374  0.11113941   0.09209876  0.09682826
# rmsle                   0.06798698  0.07939978   0.06749294  0.07100219

# %% [markdown]
# ## Predicciones

# %%
# ============================= Predicciones ====================================== #

# Train
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict)

# Test (Train)
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict)

# Test (Submission)
predichos_subm <- h2o.predict(xgb, as.h2o(dataTest)) %>%
  as.data.frame() %>% pull(predict)
predichos_subm[predichos_subm > 1] <- 1 
dataTest %>% 
  select(Square_ID) %>% 
  mutate(target = predichos_subm) ->
  subm6


# Exportando predicciones
write.csv(subm6, file = "subm6.csv", row.names = FALSE)

RMSE <- function(pred, obs, na.rm = FALSE){
  sqrt(mean((pred - obs)^2, na.rm = na.rm))
}

data.frame(
  data = c("Train", "Test"),
  RMSE = c(RMSE(pred = predichos_train, obs = as.vector(datos_train_h2o$target)),
           RMSE(pred = predichos_test, obs = as.vector(datos_test_h2o$target)))
)
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   data  RMSE
# 1 Train 0.07222417
# 2 Test  0.09332565

# %% [markdown]
# ## Importancia de variables

# %%
h2o.varimp_plot(xgb, num_of_features = ncol(dataTrain))
# Out:
# Plot with title “Variable Importance: XGBOOST”

# %% [markdown]
# ## Guardar modelo

# %%
h2o.saveModel(xgb, path = "XGB_Subm6", force = TRUE)
# Out:
# [1] "/content/XGB_Subm6/xgb_s6"

# %% [markdown]
# ## Gráficos

# %%
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict)
hist(predichos_train)
# Out:
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_train”

# %%
plot(predichos_train, as.vector(datos_train_h2o$target))
# Out:
# plot without title

# %%
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict) 
hist(predichos_test)
# Out:
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_test”

# %%
plot(predichos_test, as.vector(datos_test_h2o$target))
# Out:
# plot without title

# %%
hist(predichos_subm)
# Out:
# Plot with title “Histogram of predichos_subm”
