# %% [markdown]
# UNICEF Arm 2030 Vision #1: Flood Prediction in Malawi
# =============================================
# Edimer David Jaramillo
# Abril de 2020

# %% [markdown]
# ## Instalando y cargando bibliotecas

# %%
install.packages("h2o", dependencies = TRUE)
library(tidyverse)
library(h2o)

# %% [markdown]
# ## Importando datos

# %%
load("/content/Datos3_2015_Train.Rdata")
load("/content/Datos3_2019_Test.Rdata")

# %% [markdown]
# ## Modelo XGBoost

# %%
# Iniciando h2o
h2o.init(nthreads = -1, port = 54321, max_mem_size = "10g")

# Train y Test h2o
df_train <- df_train15

# Datos h2o
datos_h2o <- as.h2o(x = df_train, destination_frame = "datos_h2o")

particiones <- h2o.splitFrame(data = datos_h2o, ratios = c(0.7, 0.20),
                              seed = 123)
datos_train_h2o <- h2o.assign(data = particiones[[1]], key = "datos_train_H2O")
datos_val_h2o   <- h2o.assign(data = particiones[[2]], key = "datos_val_H2O")
datos_test_h2o  <- h2o.assign(data = particiones[[3]], key = "datos_test_H2O")

# Se define la variable respuesta y los predictores.
var_respuesta <- "target"

# Para este modelo se emplean todos los predictores disponibles.
predictores   <- setdiff(h2o.colnames(datos_train_h2o), var_respuesta)

# Modelo XGB h2o
xgb <- h2o.xgboost(x = predictores
                  ,y = var_respuesta
                  ,training_frame = datos_train_h2o
                  ,validation_frame = datos_val_h2o
                  ,model_id = "xgb_S48"
                  ,stopping_rounds = 5
                  ,stopping_metric = "RMSE"
                  ,distribution = "poisson"
                  ,score_tree_interval = 1
                  ,learn_rate=0.05
                  ,ntrees=1500
                  ,subsample = 0.9
                  ,colsample_bytree = 1
                  ,tree_method = "hist"
                  ,grow_policy = "lossguide"
                  ,booster = "gbtree"
                  ,gamma = 1,
                  ,max_runtime_secs = 3600
                  ,nfolds = 10,
                  ,seed = 123,
                  max_depth = 10,
                  min_rows = 10)
# Out:
# H2O is not running yet, starting it now...
#
# Note:  In case of errors look at the following log files:
#     /tmp/Rtmpk4jZah/file7d2ea1f80f/h2o_UnknownUser_started_from_r.out
#     /tmp/Rtmpk4jZah/file7d21ffb177/h2o_UnknownUser_started_from_r.err
#
#
# Starting H2O JVM and connecting: .. Connection successful!
#
# R is connected to the H2O cluster:
#     H2O cluster uptime:         2 seconds 658 milliseconds
#     H2O cluster timezone:       Etc/UTC
#     H2O data parsing timezone:  UTC
#     H2O cluster version:        3.30.0.1
#     H2O cluster version age:    8 days
#     H2O cluster name:           H2O_started_from_R_root_vjv889
#     H2O cluster total nodes:    1
#     H2O cluster total memory:   10.00 GB
#     H2O cluster total cores:    2
#     H2O cluster allowed cores:  2
#     H2O cluster healthy:        TRUE
#     H2O Connection ip:          localhost
#     H2O Connection port:        54321
#     H2O Connection proxy:       NA
#     H2O Internal Security:      FALSE
#     H2O API Extensions:         Amazon S3, XGBoost, Algos, AutoML, Core V3, TargetEncoder, Core V4
#     R Version:                  R version 3.6.3 (2020-02-29)
#
#   |======================================================================| 100%
#   |======================================================================| 100%

# %%
xgb
# Out:
# Model Details:
# ==============
#
# H2ORegressionModel: xgboost
# Model ID:  xgb_S48
# Model Summary:
#   number_of_trees
# 1             122
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on training data. **
#
# MSE:  0.008730124
# RMSE:  0.09343513
# MAE:  0.03943558
# RMSLE:  0.06914545
# Mean Residual Deviance :  0.2785594
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on validation data. **
#
# MSE:  0.0124996
# RMSE:  0.1118016
# MAE:  0.04540907
# RMSLE:  0.08057976
# Mean Residual Deviance :  0.2962631
#
#
# H2ORegressionMetrics: xgboost
# ** Reported on cross-validation data. **
# ** 10-fold cross-validation on training data (Metrics computed for combined holdout predictions) **
#
# MSE:  0.01274142
# RMSE:  0.1128779
# MAE:  0.04751642
# RMSLE:  0.08231324
# Mean Residual Deviance :  0.2976581
#
#
# Cross-Validation Metrics Summary:
#                               mean           sd  cv_1_valid  cv_2_valid
# mae                     0.04749606 0.0045811655 0.051394675  0.04381353
# mean_residual_deviance  0.29770505  0.028962838  0.33800673   0.2798962
# mse                    0.012752454 0.0018744287 0.013807874 0.011085507
# r2                       0.7587123  0.025548495   0.7570334  0.78883016
# residual_deviance       0.29770505  0.028962838  0.33800673   0.2798962
# rmse                    0.11267568  0.007933397 0.117506914  0.10528774
# rmsle                   0.08223553 0.0046154708 0.086158976  0.07833507
#                         cv_3_valid  cv_4_valid  cv_5_valid   cv_6_valid
# mae                    0.049712934    0.046569 0.046773903  0.050063565
# mean_residual_deviance    0.304315   0.3233174  0.30347613   0.29314646
# mse                    0.012253763 0.013467759 0.012589731 0.0118002575
# r2                      0.78867847   0.7866312    0.760629   0.76277953
# residual_deviance         0.304315   0.3233174  0.30347613   0.29314646
# rmse                    0.11069672 0.116050676  0.11220397   0.10862899
# rmsle                   0.08026679  0.08317626  0.08381692   0.08011026
#                         cv_7_valid  cv_8_valid  cv_9_valid cv_10_valid
# mae                    0.056496363 0.040482663 0.046009094 0.043644875
# mean_residual_deviance  0.33744928   0.2559592   0.2769929  0.26449135
# mse                    0.017392883 0.010836534  0.01192928 0.012360951
# r2                       0.7216716   0.7552661   0.7163643  0.74923944
# residual_deviance       0.33744928   0.2559592   0.2769929  0.26449135
# rmse                    0.13188207  0.10409867  0.10922124 0.111179814
# rmsle                   0.09250633  0.07594091 0.081821956  0.08022184

# %% [markdown]
# ## Predicciones

# %%
# ============================= Predicciones ====================================== #

# Train
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict)

# Test (Train)
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict)

# Test (Submission)
predichos_subm <- h2o.predict(xgb, as.h2o(df_test19)) %>%
  as.data.frame() %>% pull(predict)
df_test19 %>% 
  select(Square_ID) %>% 
  mutate(target = predichos_subm) ->
  subm48

# Exportando predicciones
write.csv(subm48, file = "subm48.csv", row.names = FALSE)

RMSE <- function(pred, obs, na.rm = FALSE){
  sqrt(mean((pred - obs)^2, na.rm = na.rm))
}

data.frame(
  data = c("Train", "Test"),
  RMSE = c(RMSE(pred = predichos_train, obs = as.vector(datos_train_h2o$target)),
           RMSE(pred = predichos_test, obs = as.vector(datos_test_h2o$target)))
)
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   |======================================================================| 100%
#   data  RMSE
# 1 Train 0.09343513
# 2 Test  0.10926520

# %%
predichos_train <- h2o.predict(xgb, datos_train_h2o) %>%
  as.data.frame() %>% pull(predict)
hist(predichos_train)
# Out:
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_train”

# %%
plot(predichos_train, as.vector(datos_train_h2o$target))
# Out:
# plot without title

# %%
predichos_test <- h2o.predict(xgb, datos_test_h2o) %>%
  as.data.frame() %>% pull(predict) 
hist(predichos_test)
# Out:
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_test”

# %%
plot(predichos_test, as.vector(datos_test_h2o$target))
# Out:
# plot without title

# %%
predichos_subm <- h2o.predict(xgb, as.h2o(df_test19)) %>%
  as.data.frame() %>% pull(predict) 
hist(predichos_subm)
# Out:
#   |======================================================================| 100%
#   |======================================================================| 100%
# Plot with title “Histogram of predichos_subm”

# %%
h2o.varimp_plot(xgb, num_of_features = 30)
# Out:
# Plot with title “Variable Importance: XGBOOST”

# %%
h2o.saveModel(xgb, path = "XGB_Subm48", force = TRUE)
# Out:
# [1] "/content/XGB_Subm48/xgb_S48"

# %%
h2o.shutdown()
